# %% [markdown]
# <a href="https://colab.research.google.com/github/Komal05010/CSE-AIML-Practicals/blob/main/Practical-01/Practical_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Practical 01")
print("Hello from Google Colab!")
# Out:
# Practical 01
# Hello from Google Colab!
